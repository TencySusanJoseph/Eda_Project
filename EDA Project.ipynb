# %% [markdown]
# ###                           EXPLORATORY DATA ANALYSIS
# ### PROJECT ON SUPERSTORES

# %% [markdown]
# ##### With developing requests and merciless contests on the lookout, a Superstore Giant is looking for your insight in understanding what turns out best for them. They migt want to comprehend which Products,region,categories and customer segments they ought to target or keep away from.

# %%
#Read the data
import pandas as pd
df=pd.read_excel(r'C:\Users\DELL\Downloads\Superstore.xlsx')
df
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  Number of records Order.Date  \
# 0      Lycoris Saunders       0.0     US                  1 2011-01-07
# ...

# %%
#Remove space and comma
for i in df:
    j=i.replace(' ','_',)
    df.rename(columns={i:j.capitalize()},inplace=True)
df
# Out:
#               Category         City        Country Customer.id  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.name  Discount Market  Number_of_records Order.date  \
# 0      Lycoris Saunders       0.0     US                  1 2011-01-07
# ...

# %%
# Summerizing the data
df.describe().T
# Out:
#                      count                           mean  \
# Discount           51290.0                       0.142908
# Number_of_records  51290.0                            1.0
# Order.date           51290  2013-05-11 21:26:49.155780864
# Profit             51290.0                      28.610982
# Quantity           51290.0                       3.476545
# Row.id             51290.0                        25645.5
# Sales              51290.0                      246.49844
# Ship.date            51290  2013-05-15 20:42:42.745174784
# Shipping.cost      51290.0                      26.375818
# Year               51290.0                    2012.777208
# Weeknum            51290.0                      31.287112
#
#                                    min                  25%  \
# Discount                           0.0                  0.0
# Number_of_records                  1.0                  1.0
# Order.date         2011-01-01 00:00:00  2012-06-19 00:00:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Category           51290 non-null  object
#  1   City               51290 non-null  object
#  2   Country            51290 non-null  object
#  3   Customer.id        51290 non-null  object
#  4   Customer.name      51290 non-null  object
#  5   Discount           51290 non-null  float64
#  6   Market             51290 non-null  object
#  7   Number_of_records  51290 non-null  int64
#  8   Order.date         51290 non-null  datetime64[ns]
#  9   Order.id           51290 non-null  object
#  10  Order.priority     51290 non-null  object
#  11  Product.id         51290 non-null  object
#  12  Product.name       51290 non-null  object
#  13  Profit             51290 non-null  float64
#  14  Quantity           51290 non-null  int64
# ...

# %% [markdown]
# ##### 1. How many columns in the dataset contains missing values?

# %%
df.isna().sum()
# Out:
# Category             0
# City                 0
# Country              0
# Customer.id          0
# Customer.name        0
# Discount             0
# Market               0
# Number_of_records    0
# Order.date           0
# Order.id             0
# Order.priority       0
# Product.id           0
# Product.name         0
# Profit               0
# Quantity             0
# Region               0
# Row.id               0
# Sales                0
# Segment              0
# Ship.date            0
# Ship.mode            0
# Shipping.cost        0
# State                0
# Sub.category         0
# Year                 0
# Market2              0
# Weeknum              0
# dtype: int64

# %% [markdown]
# ##### All columns are free of missing values. Having all columns free of missing values is essential for data integrity and analysis.

# %% [markdown]
# #### 2. Which products has maximum sale?

# %%
df.groupby('Product.name')['Sales'].sum().nlargest(5)
import seaborn as sns
import matplotlib.pyplot as plt
max_sale=df.groupby('Product.name')['Sales'].sum().nlargest(5)
sns.barplot(x=max_sale.values,y=max_sale.index,palette='Paired')
plt.title('Top 10 Products',size=20,pad=20)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17184\2133756699.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=max_sale.values,y=max_sale.index,palette='Paired')

# %% [markdown]
# ##### Apple smartphones have the maximum sale in the superstore" indicates a notable preference among customers for Apple products over other smartphone brands.

# %% [markdown]
# #### 3. Which was the most ordered product?

# %%
df.groupby('Product.name')['Quantity'].sum().nlargest(5)
# Out:
# Product.name
# Staples                                  876
# Cardinal Index Tab, Clear                337
# Eldon File Cart, Single Width            321
# Rogers File Cart, Single Width           262
# Sanford Pencil Sharpener, Water Color    259
# Name: Quantity, dtype: int64

# %%
most_ordered=df.groupby('Product.name')['Quantity'].sum().nlargest(5)
import seaborn as sns
import matplotlib.pyplot as plt
plt.xticks(rotation=90)
sns.barplot(x=most_ordered.index,y=most_ordered.values,palette='tab10')
plt.title('Most Ordered Products',size=20,pad=20)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17184\2147696722.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_ordered.index,y=most_ordered.values,palette='tab10')

# %% [markdown]
# ##### Staples are the most ordered product in Superstores,it suggests that customers have a consistent need for essential everyday items like office supplies, stationery, or other commonly used products. This trend could reflect the importance of staples in both personal and business settings, where they are essential for day-to-day operations.

# %% [markdown]
# #### 4. Which was the least ordered product?

# %%
df.groupby('Product.name')['Quantity'].sum().nsmallest(5)
# Out:
# Product.name
# Boston 1900 Electric Pencil Sharpener                                        1
# Bush Saratoga Collection 5-Shelf Bookcase, Hanover Cherry, *Special Order    1
# Chromcraft Training Table, Adjustable Height                                 1
# Global Enterprise Series Seating Low-Back Swivel/Tilt Chairs                 1
# Penpower WorldCard Pro Card Scanner                                          1
# Name: Quantity, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
least_ord=df.groupby('Product.name')['Quantity'].sum().nsmallest(5)
sns.barplot(x=least_ord.values,y=least_ord.index,palette="Set2")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17184\4265129121.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=least_ord.values,y=least_ord.index,palette="Set2")

# %% [markdown]
# ##### It is found to be five products were ordered less, which are Boston 1900 Electric Pencil Sharpener,Bush Saratoga Collection 5-Shelf Bookcase,Chromcraft Training Table,Global Enterprise Series Seating Low-Back Swivel/Tilt Chairs,Penpower WorldCard Pro Card Scanner. The quantity remains same for all.

# %% [markdown]
# #### 5. Which Country brought more products?

# %%
df.groupby('Country')['Product.name'].sum().sort_values(ascending=False).head(5)
# Out:
# Country
# United States    Xerox 225Wirebound Service Call Books, 5 1/2" ...
# Mongolia         Wilson Jones Index Tab, DurableEldon Lockers, ...
# China            Wilson Jones Hole Reinforcements, DurableJiffy...
# Italy            Wilson Jones Binding Machine, ClearSanford Ske...
# Gabon            Wilson Jones Binder Covers, RecycledCameo Peel...
# Name: Product.name, dtype: object

# %% [markdown]
# ##### "United States brought more products," it suggests that the United States, as a market or entity, has been a significant purchaser or importer of products compared to other regions or countries..

# %% [markdown]
# #### 6. Which region generates the most sales?

# %%
import matplotlib.pyplot as plt
ki=df.groupby('Region')['Sales'].sum()
print(ki)
lables=['Africa','Canada','Caribbean','Central','Central Asia','EMEA','East','North','North Asia','Oceania','South','Southeast Asia','West']
plt.title('Sales over Region',size=20,pad=20)
plt.pie(ki,labels=lables)
plt.show()
# Out:
# Region
# Africa             783776
# Canada              66932
# Caribbean          324281
# Central           2822399
# Central Asia       752839
# EMEA               806184
# East               678834
# North             1248192
# North Asia         848349
# Oceania           1100207
# South             1600960
# Southeast Asia     884438
# West               725514
# Name: Sales, dtype: int64

# %% [markdown]
# ##### The central region generates the highest sales can help businesses tailor their strategies, allocate resources effectively, and capitalize on the strengths of this region to drive further growth and profitability.

# %% [markdown]
# #### 7. Which country has minimum sale?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ki=df.groupby('Country')['Sales'].sum().nsmallest(5)
print(ki)
lables=['Equatorial Guinea','Armenia','Eritrea','Macedonia','Tajikistan']
plt.pie(ki,labels=lables)
plt.show()
# Out:
# Country
# Equatorial Guinea    150
# Armenia              156
# Eritrea              188
# Macedonia            210
# Tajikistan           242
# Name: Sales, dtype: int64

# %% [markdown]
# ##### Equatorial Guinea has minimum sales. If Equatorial Guinea has minimum sales, it suggests that this particular market or region contributes the least amount of revenue compared to other areas.

# %% [markdown]
# #### 8. What are the top selling products in the Superstore?

# %%
df.groupby('Product.name')['Sales'].sum().sort_values(ascending=False).head()
import seaborn as sns
import matplotlib.pyplot as plt
plt.xticks(rotation=90)
ki=df.groupby('Product.name')['Sales'].sum().sort_values(ascending=False).head()
sns.barplot(x=ki.index,y=ki.values,palette="Paired")
plt.title('Total Selling Products',size=20,pad=20)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17184\2139482720.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ki.index,y=ki.values,palette="Paired")

# %% [markdown]
# ##### Top selling products in a Superstore typically encompass a variety of categories catering to diverse consumer needs. While specific data may vary based on location and time, some common top-selling products include Apple Smart Phone, Cisco Smart Phone,Motorola Smart Phone, Nokia Smart phone, Canon image advanced copier.These products tend to consistently perform well due to their essential nature or high consumer demand.However, actual top sellers may vary depending on factors such as promotional activities, consumer preferences, and market trends.

# %% [markdown]
# #### 9. How many items were ordered in total?

# %%
total_items_orders=df.Quantity.sum()
print(total_items_orders)
# Out:
# 178312

# %% [markdown]
# ##### Knowing that 178,312 items were ordered in total provides a crucial insight into the overall volume of sales or transactions processed by the entity in question. This information can be valuable for various purposes as Performance analysis, inventory management, Revenue calculation, Trend identification and forecasting.

# %% [markdown]
# #### 10. Which shipment mode was used frequently?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
sns.countplot(x='Ship.mode',data=df,palette='Set2')
plt.title("Shipping mode distribution")
plt.xlabel("Ship.mode")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17184\2493960903.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Ship.mode',data=df,palette='Set2')

# %% [markdown]
# ##### Standard Class was most used for shipping.The most frequently used shipment mode can vary depending on factors such as the nature of the goods being transported, geographic considerations, cost-effectiveness, and delivery requirements.

# %% [markdown]
# #### 11. Which Category has highest discount rate?

# %%
df.groupby('Category')['Discount'].sum().reset_index(name='Size')
# Out:
#           Category      Size
# 0        Furniture  1660.030
# 1  Office Supplies  4297.190
# 2       Technology  1372.508

# %%
import seaborn as sns
df2=df.groupby('Category')['Discount'].sum().reset_index(name='Discount')
sns.barplot(x='Category',y='Discount',palette='Set1',data=df2)
plt.title("Category-Discount",size=20,pad=20)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17184\1459852276.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category',y='Discount',palette='Set1',data=df2)

# %% [markdown]
# ##### Office Supplies have the highest discount rate compared to other categories. It suggests that the superstore offers more significant discounts or promotions on office supply products relative to other product categories.

# %% [markdown]
# #### 12. Which Market generates the most sales?

# %%
df['Market']
df.groupby('Market')['Sales'].sum().sort_values(ascending=False).head()
# Out:
# Market
# APAC     3585833
# EU       2938139
# US       2297354
# LATAM    2164687
# EMEA      806184
# Name: Sales, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data_set=df
sns.lineplot(x='Market',y='Sales',data=data_set,palette='Set2')
plt.title('Market-Sales',size=20,pad=20)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17184\269122099.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='Market',y='Sales',data=data_set,palette='Set2')

# %% [markdown]
# ##### Asia-Pacific (APAC) region generates the most sales, it suggests that the market within the APAC region outperforms other regions in terms of sales volume.

# %% [markdown]
# #### 13. Most purchasing customer

# %%
df['Customer.name']
df.groupby('Customer.name')['Sales'].sum().sort_values(ascending=False).head()
# Out:
# Customer.name
# Tom Ashbrook          40489
# Tamara Chand          37453
# Greg Tran             35552
# Christopher Conant    35187
# Sean Miller           35170
# Name: Sales, dtype: int64

# %% [markdown]
# ##### Tom Ashbrook is the customer who purchases the most.

# %% [markdown]
# #### 14. Which date had the highest number of orders?

# %%
import pandas as pd
pivot=pd.pivot_table(
    data=df,
    index=df['Order.date'].dt.date,
    values='Quantity',
    aggfunc='sum'
)
print(pivot)
pivot.sort_values(by='Quantity',ascending=False).head().reset_index()
# Out:
#             Quantity
# Order.date
# 2011-01-01        19
# 2011-01-02         1
# 2011-01-03        48
# 2011-01-04        52
# 2011-01-05        24
# ...              ...
# 2014-12-27       188
# 2014-12-28        51
# 2014-12-29       408
# 2014-12-30       284
# 2014-12-31       223
#
# [1430 rows x 1 columns]
#    Order.date  Quantity
# 0  2014-06-18       461
# 1  2014-11-18       458
# 2  2014-11-20       443
# 3  2012-11-13       419
# 4  2014-12-29       408

# %%
import matplotlib.pyplot as plt
import datetime
x = [datetime.datetime(2014,6,18), datetime.datetime(2014,11,18),
     datetime.datetime(2014,11,20), datetime.datetime(2012,11,13),datetime.datetime(2014,12,29)]
y = [461,458,443,419,408]
ax = plt.subplot(111)
ax.bar(x, y, width=10)
ax.xaxis_date()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### The date with highest number of orders was 18/06/2014.

# %% [markdown]
# #### 15. Which shipment mode has highest Sales and Profit?

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_stackb = df[['Ship.mode','Sales','Profit']]
# taking a groupby on category and then ship mode...
df_stackb = df_stackb.groupby(['Ship.mode']).sum().reset_index()
plt.figure(figsize=[10,15])
plt.subplot(3,1,1)
plt.bar(x=df_stackb['Ship.mode'], height=df_stackb['Sales'], color='#F05454')
plt.bar(x=df_stackb['Ship.mode'], height=df_stackb['Profit'], bottom=df_stackb['Sales'], color='#30475E')
plt.title("Sales & Profit Across Ship Modes", size=20, pad=20)
plt.legend(['Sales','Profit'])

# %% [markdown]
# ##### Based on the analysis of the sales data, it's evident that the standard class shipping mode has both the highest sales and profit figures compared to other shipment modes. This conclusion indicates that standard class shipping is not only popular among customers but also contributes significantly to the profitability of the business.

# %% [markdown]
# #### 16. How many days it will take for the order to be shipped after it has been placed?

# %%
diff=df['Ship.date']-df['Order.date']
days=diff.mean()
print(days)
# Out:
# 3 days 23:15:53.589393644

# %% [markdown]
# ##### It will take approximately 3 days to be shipped after it has been placed.A three-day shipping timeframe suggests a relatively efficient delivery process, which could contribute to the popularity and profitability of standard class shipping.

# %% [markdown]
# #### 17. Which is the top selling sub category?

# %%
Most_sold=df.groupby('Sub.category')['Sales'].sum().sort_index(ascending=False)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data_set=df
plt.figure(figsize=(10,8))
sns.pointplot(x=Most_sold.index, y=Most_sold.values)
plt.xticks(rotation=90)
plt.xlabel('Sub.category')
plt.ylabel('Sales')
plt.title("Top selling Sub Category",size=20,pad=20)
plt.show()

# %% [markdown]
# ##### Phones are the top selling subcategory. Recognizing phones as the top-selling subcategory suggests that there is high demand for these products among customer base.

# %% [markdown]
# #### 18. What is the state with the highest profit?

# %%
high_prof=df.groupby('State')['Profit'].sum().nlargest(10)
print(high_prof)
# Out:
# State
# England                   99907.73100
# California                76381.38710
# New York                  74038.54860
# Ile-de-France             44055.92400
# New South Wales           43695.98400
# North Rhine-Westphalia    42347.87100
# San Salvador              35883.37700
# Washington                33402.65170
# Michigan                  24463.18760
# São Paulo                 21878.02388
# Name: Profit, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.xticks(rotation=70)
sns.barplot(x=high_prof.index,y=high_prof.values,palette="Paired")
plt.title("Profit over States",size=20)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17184\2089985981.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=high_prof.index,y=high_prof.values,palette="Paired")

# %% [markdown]
# #####  England has highest profit.  Leveraging insights from England's performance can inform strategic decisions aimed at further capitalizing on opportunities, optimizing operations, and driving continued growth and profitability for the business.

# %% [markdown]
# #### 19. Total profit with respect to region

# %%
#(we can denote region across profit as rgn_pft)
rgn_pft=df.groupby('Region')['Profit'].sum().sort_values(ascending=False)
print(rgn_pft)
import seaborn as sns
import matplotlib.pyplot as plt
plt.xticks(rotation=90)
sns.barplot(x=rgn_pft.index,y=rgn_pft.values,palette="Set2")
plt.title("Profit over Region",size=20,pad=20)
plt.show()
# Out:
# Region
# Central           311403.98164
# North             194597.95252
# North Asia        165578.42100
# South             140355.76618
# Central Asia      132480.18700
# Oceania           120089.11200
# West              108418.44890
# East               91522.78000
# Africa             88871.63100
# EMEA               43897.97100
# Caribbean          34571.32104
# Southeast Asia     17852.32900
# Canada             17817.39000
# Name: Profit, dtype: float64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17184\2026864032.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rgn_pft.index,y=rgn_pft.values,palette="Set2")

# %% [markdown]
# ##### The central region emerges as the location with the highest profit, indicating its significance as a profitable market for the business.

# %% [markdown]
# ##### In conclusion, the analysis of the provided sales data offers valuable insights into various aspects of the business operations: Apple Smart Phone emerges as the top-selling product, indicating strong consumer demand for smartphones. Staples are identified as the most ordered product in Superstores, underscoring their importance in customer purchases. While certain products like smartphones and office supplies perform well, others, such as the Boston 1900 Electric Pencil Sharpener and Bush Saratoga Collection 5-Shelf Bookcase, exhibit lower demand. The United States emerges as the top buyer, while the central region leads in generating sales. However, Equatorial Guinea is identified as having minimal sales, highlighting potential areas for improvement or exploration.The Asia-Pacific (APAC) region emerges as the top sales generator, indicating its strong market performance compared to other regions. Standard class shipping is the most frequently used mode, suggesting its efficiency and popularity among customers. The approximate three-day shipping timeframe further enhances customer satisfaction and contributes to the mode's profitability. Tom Ashbrook emerges as the top purchasing customer, representing a valuable segment for targeted marketing efforts.Phones stand out as the top-selling subcategory, reflecting high demand among customers.England emerges as the location with the highest profit, indicating its significance as a profitable market for the business.
#
#
# ##### In summary, these insights can inform strategic decisions aimed at optimizing product offerings, targeting key markets, improving shipping processes, and maximizing profitability. Continuously monitoring and analyzing sales data will be essential for maintaining competitiveness and driving sustainable growth in the business.
